# %%
# Blake Myers and Nicolas Stencel, Part 2 of the final project for CSCE 5210 
# Creating a simple neural network to extract info about our text

# %%
import stanza_nlp as nlp
import csv
from sklearn.preprocessing import OneHotEncoder
import numpy as np
from collections import defaultdict, Counter
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import load_model

# %%
def tsv2mat(fname) :
  with open(fname) as f:
     wss = csv.reader(f, delimiter='\t')
     return list(wss)

class Data :
  def __init__(self,fname='texts/english') :
    wss = tsv2mat("out/"+fname+".tsv")
    self.sents=tsv2mat("out/"+fname+"_sents.tsv")
    occs=defaultdict(set)
    sids=set()
    for f,r,t,id in wss:
      id=int(id)
      occs[(f,r,t)].add(id)
      sids.add(id)
    self.occs=occs

    X,Y=list(zip(*list(occs.items())))
    X = np.array(X)
    y0 = np.array(sorted(map(lambda x:[x],sids)))

    enc_X = OneHotEncoder(handle_unknown='ignore')
    enc_y = OneHotEncoder(handle_unknown='ignore')
    enc_X.fit(X)
    enc_y.fit(y0)
    hot_X = enc_X.transform(X).toarray()
    self.enc_X = enc_X
    self.enc_y = enc_y
    self.X=X
    ms=[]
    for ys in Y :
      m = np.array([[0]],dtype=np.float32)
      for v in ys :
        m0=enc_y.transform(np.array([[v]])).toarray()
        m = np.logical_or(m,m0)
        m=np.array(np.logical_or(m,m0),dtype=np.float32)
      ms.append(m[0])
    hot_y=np.array(ms)

    self.hot_X=hot_X
    self.hot_y =hot_y

    print('\nFINAL DTATA SHAPES','X',hot_X.shape,'y',hot_y.shape,'\n')

class Query(Data) :
  def __init__(self,fname='texts/english'):
    super().__init__(fname=fname)
    self.nlp_engine=nlp.NLP()

  def ask(self,text=None):
    if not text: text = input("Query:")
    else: print("Query:",text)

    self.nlp_engine.from_text(text)
    sids=[]
    for f,r,t,_ in self.nlp_engine.facts() :
      sids.extend(self.occs.get((f,r,t),[]))
    self.show_answers(sids)

  def show_answers(self, sids, k=3):
    c = Counter(sids)
    print('\nHIT COUNTS:',c,"\n")
    best = c.most_common(k)
    for sid, _ in best:
      id, sent = self.sents[sid]
      print(id, ':', sent)
    print("")

class Inferencer(Query) :
  def __init__(self,fname='texts/english'):
    super().__init__(fname=fname)
    self.model = load_model(fname+"_model")

  def query(self,text=None):
    if not text: text = input("Query:")
    else: print("Query:", text)
    self.nlp_engine.from_text(text)
    X=[]
    for f, r, t, _ in self.nlp_engine.facts():
      X.append([f,r,t])
    X = np.array(X)
    hot_X = self.enc_X.transform(X).toarray()
    y=self.model.predict(hot_X)
    m=self.enc_y.inverse_transform(y)
    sids=m.flatten().tolist()
    self.show_answers(sids)

class Trainer(Data) :
  def __init__(self,fname='texts/english'):
    super().__init__(fname=fname)
    model = keras.Sequential()
    model.add(layers.Dense(128, input_dim=self.hot_X.shape[1], activation='relu'))
    model.add(layers.Dense(self.hot_y.shape[1], activation='sigmoid'))
    model.summary()
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(self.hot_X, self.hot_y, epochs=100, batch_size=16)

    model.save(fname+"_model")

    loss, accuracy = model.evaluate(self.hot_X, self.hot_y)
    print('Accuracy:', round(100 * accuracy, 2), ', % Loss:', round(100 * loss, 2), '%')

# %%
def qtest():
    q=Query()
    q.ask(text="What do I fear above all things?")
    q.ask(text="What celebrated my arrival?")
    q.ask(text="At what time of day was I born?")
    q.ask(text="What has no further use for me and is running out?")
    q.ask(text="Which doctor had a nursing home I was born in?")
    q.ask(text="Who prophesied me?")
    q.ask(text="What type of home was I born in?")
    q.ask(text="Who broke his toe?")
    q.ask(text="What city was I born in?")
    q.ask(text="What is crumbling and overused?")
    
def dtest():
    d=Data()
    print("X",d.hot_X.shape)
    print(d.hot_X)
    print("y",d.hot_y.shape)
    print(d.hot_y)

def dtests():
    dtest('out/texts/english.tsv')

def ntest() : 
    t=Trainer()
    i=Inferencer()
    print("\n\n")
    print("ALGORITHMICALLY DERIVED ANSWERS:\n")
    i.ask(text="What do I fear above all things?")
    i.ask(text="What celebrated my arrival?")
    i.ask(text="At what time of day was I born?")
    i.ask(text="What has no further use for me and is running out?")
    i.ask(text="Which doctor had a nursing home I was born in?")
    i.ask(text="Who prophesied me?")
    i.ask(text="What type of home was I born in?")
    i.ask(text="Who broke his toe?")
    i.ask(text="What city was I born in?")
    i.ask(text="What is crumbling and overused?")
    
    print("\n")
    print("NEURAL NET'S ANSWERS:\n")
    i.query(text="What do I fear above all things?")
    i.query(text="What celebrated my arrival?")
    i.query(text="At what time of day was I born?")
    i.query(text="What has no further use for me and is running out?")
    i.query(text="Which doctor had a nursing home I was born in?")
    i.query(text="Who prophesied me?")
    i.query(text="What type of home was I born in?")
    i.query(text="Who broke his toe?")
    i.query(text="What city was I born in?")
    i.query(text="What is crumbling and overused?")
    
if __name__=="__main__" :
  ntest()
# Out:
# FINAL DTATA SHAPES X (423, 415) y (423, 25)
#
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               53248
# _________________________________________________________________
# dense_1 (Dense)              (None, 25)                3225
# =================================================================
# Total params: 56,473
# Trainable params: 56,473
# Non-trainable params: 0
# _________________________________________________________________
# Train on 423 samples
# Epoch 1/100
# 423/423 [==============================] - 2s 4ms/sample - loss: 3.2585 - accuracy: 0.0922
# Epoch 2/100
# 423/423 [==============================] - 0s 665us/sample - loss: 3.1742 - accuracy: 0.2624
# Epoch 3/100
# 423/423 [==============================] - 0s 907us/sample - loss: 3.0828 - accuracy: 0.2837
# Epoch 4/100
# 423/423 [==============================] - 0s 758us/sample - loss: 2.9649 - accuracy: 0.2813
# Epoch 5/100
# 423/423 [==============================] - 0s 397us/sample - loss: 2.8096 - accuracy: 0.2813
# Epoch 6/100
# 423/423 [==============================] - 0s 333us/sample - loss: 2.6073 - accuracy: 0.2624
# Epoch 7/100
# 423/423 [==============================] - 0s 354us/sample - loss: 2.3442 - accuracy: 0.2222
# Epoch 8/100
# 423/423 [==============================] - 0s 322us/sample - loss: 2.0110 - accuracy: 0.2317
# Epoch 9/100
# 423/423 [==============================] - 0s 321us/sample - loss: 1.5862 - accuracy: 0.6454
# Epoch 10/100
# 423/423 [==============================] - 0s 333us/sample - loss: 1.1045 - accuracy: 0.9338
# Epoch 11/100
# 423/423 [==============================] - 0s 471us/sample - loss: 0.7423 - accuracy: 0.9669
# Epoch 12/100
# 423/423 [==============================] - 0s 282us/sample - loss: 0.5137 - accuracy: 0.9716
# Epoch 13/100
# 423/423 [==============================] - 0s 288us/sample - loss: 0.3776 - accuracy: 0.9835
# Epoch 14/100
# 423/423 [==============================] - 0s 263us/sample - loss: 0.2938 - accuracy: 0.9858
# Epoch 15/100
# 423/423 [==============================] - 0s 277us/sample - loss: 0.2355 - accuracy: 0.9811
# Epoch 16/100
# 423/423 [==============================] - 0s 283us/sample - loss: 0.1959 - accuracy: 0.9858
# Epoch 17/100
# 423/423 [==============================] - 0s 287us/sample - loss: 0.1670 - accuracy: 0.9905
# Epoch 18/100
# 423/423 [==============================] - 0s 289us/sample - loss: 0.1464 - accuracy: 0.9882
# Epoch 19/100
# 423/423 [==============================] - 0s 414us/sample - loss: 0.1292 - accuracy: 0.9929
# Epoch 20/100
# 423/423 [==============================] - 0s 504us/sample - loss: 0.1165 - accuracy: 0.9882
# Epoch 21/100
# 423/423 [==============================] - 0s 459us/sample - loss: 0.1059 - accuracy: 0.9929
# Epoch 22/100
# 423/423 [==============================] - 0s 552us/sample - loss: 0.0974 - accuracy: 0.9858
# Epoch 23/100
# 423/423 [==============================] - 0s 452us/sample - loss: 0.0899 - accuracy: 0.9953
# Epoch 24/100
# 423/423 [==============================] - 0s 489us/sample - loss: 0.0839 - accuracy: 0.9858
# Epoch 25/100
# 423/423 [==============================] - 0s 505us/sample - loss: 0.0783 - accuracy: 0.9882
# Epoch 26/100
# 423/423 [==============================] - 0s 690us/sample - loss: 0.0741 - accuracy: 0.9882
# Epoch 27/100
# 423/423 [==============================] - 0s 901us/sample - loss: 0.0703 - accuracy: 0.9882
# Epoch 28/100
# 423/423 [==============================] - 0s 738us/sample - loss: 0.0669 - accuracy: 0.9929
# Epoch 29/100
# 423/423 [==============================] - 0s 819us/sample - loss: 0.0640 - accuracy: 0.9929
# Epoch 30/100
# 423/423 [==============================] - 0s 592us/sample - loss: 0.0611 - accuracy: 0.9858
# Epoch 31/100
# 423/423 [==============================] - 0s 526us/sample - loss: 0.0587 - accuracy: 0.9953
# Epoch 32/100
# 423/423 [==============================] - 0s 513us/sample - loss: 0.0566 - accuracy: 0.9858
# Epoch 33/100
# 423/423 [==============================] - 0s 405us/sample - loss: 0.0548 - accuracy: 0.9929
# Epoch 34/100
# 423/423 [==============================] - 0s 427us/sample - loss: 0.0530 - accuracy: 0.9858
# Epoch 35/100
# 423/423 [==============================] - 0s 517us/sample - loss: 0.0522 - accuracy: 0.9929
# Epoch 36/100
# 423/423 [==============================] - 0s 370us/sample - loss: 0.0501 - accuracy: 0.9882
# Epoch 37/100
# 423/423 [==============================] - 0s 330us/sample - loss: 0.0487 - accuracy: 0.9905
# Epoch 38/100
# 423/423 [==============================] - 0s 380us/sample - loss: 0.0476 - accuracy: 0.9882
# Epoch 39/100
# 423/423 [==============================] - 0s 412us/sample - loss: 0.0466 - accuracy: 0.9882
# Epoch 40/100
# 423/423 [==============================] - 0s 496us/sample - loss: 0.0458 - accuracy: 0.9905
# Epoch 41/100
# 423/423 [==============================] - 0s 391us/sample - loss: 0.0446 - accuracy: 0.9858
# Epoch 42/100
# 423/423 [==============================] - 0s 399us/sample - loss: 0.0438 - accuracy: 0.9929
# Epoch 43/100
# 423/423 [==============================] - 0s 471us/sample - loss: 0.0430 - accuracy: 0.9858
# Epoch 44/100
# 423/423 [==============================] - 0s 375us/sample - loss: 0.0424 - accuracy: 0.9929
# Epoch 45/100
# 423/423 [==============================] - 0s 339us/sample - loss: 0.0417 - accuracy: 0.9929
# Epoch 46/100
# 423/423 [==============================] - 0s 353us/sample - loss: 0.0411 - accuracy: 0.9929
# Epoch 47/100
# 423/423 [==============================] - 0s 353us/sample - loss: 0.0405 - accuracy: 0.9882
# Epoch 48/100
# 423/423 [==============================] - 0s 349us/sample - loss: 0.0400 - accuracy: 0.9858
# Epoch 49/100
# 423/423 [==============================] - 0s 318us/sample - loss: 0.0396 - accuracy: 0.9929
# Epoch 50/100
# 423/423 [==============================] - 0s 305us/sample - loss: 0.0390 - accuracy: 0.9882
# Epoch 51/100
# 423/423 [==============================] - 0s 457us/sample - loss: 0.0386 - accuracy: 0.9882
# Epoch 52/100
# 423/423 [==============================] - 0s 386us/sample - loss: 0.0382 - accuracy: 0.9929
# Epoch 53/100
# 423/423 [==============================] - 0s 378us/sample - loss: 0.0379 - accuracy: 0.9905
# Epoch 54/100
# 423/423 [==============================] - 0s 527us/sample - loss: 0.0375 - accuracy: 0.9905
# Epoch 55/100
# 423/423 [==============================] - 0s 348us/sample - loss: 0.0372 - accuracy: 0.9929
# Epoch 56/100
# 423/423 [==============================] - 0s 351us/sample - loss: 0.0370 - accuracy: 0.9905
# Epoch 57/100
# 423/423 [==============================] - 0s 428us/sample - loss: 0.0367 - accuracy: 0.9929
# Epoch 58/100
# 423/423 [==============================] - 0s 380us/sample - loss: 0.0362 - accuracy: 0.9882
# Epoch 59/100
# 423/423 [==============================] - 0s 363us/sample - loss: 0.0360 - accuracy: 0.9929
# Epoch 60/100
# 423/423 [==============================] - 0s 329us/sample - loss: 0.0360 - accuracy: 0.9905
# Epoch 61/100
# 423/423 [==============================] - 0s 366us/sample - loss: 0.0369 - accuracy: 0.9905
# Epoch 62/100
# 423/423 [==============================] - 0s 692us/sample - loss: 0.0364 - accuracy: 0.9929
# Epoch 63/100
# 423/423 [==============================] - 0s 418us/sample - loss: 0.0364 - accuracy: 0.9929
# Epoch 64/100
# 423/423 [==============================] - 0s 401us/sample - loss: 0.0370 - accuracy: 0.9882
# Epoch 65/100
# 423/423 [==============================] - 0s 471us/sample - loss: 0.0369 - accuracy: 0.9953
# Epoch 66/100
# 423/423 [==============================] - 0s 484us/sample - loss: 0.0351 - accuracy: 0.9858
# Epoch 67/100
# 423/423 [==============================] - 0s 376us/sample - loss: 0.0344 - accuracy: 0.9953
# Epoch 68/100
# 423/423 [==============================] - 0s 353us/sample - loss: 0.0341 - accuracy: 0.9882
# Epoch 69/100
# 423/423 [==============================] - 0s 389us/sample - loss: 0.0339 - accuracy: 0.9976
# Epoch 70/100
# 423/423 [==============================] - 0s 366us/sample - loss: 0.0337 - accuracy: 0.9858
# Epoch 71/100
# 423/423 [==============================] - 0s 426us/sample - loss: 0.0335 - accuracy: 0.9953
# Epoch 72/100
# 423/423 [==============================] - 0s 375us/sample - loss: 0.0334 - accuracy: 0.9882
# Epoch 73/100
# 423/423 [==============================] - 0s 352us/sample - loss: 0.0333 - accuracy: 0.9953
# Epoch 74/100
# 423/423 [==============================] - 0s 400us/sample - loss: 0.0331 - accuracy: 0.9882
# Epoch 75/100
# 423/423 [==============================] - 0s 417us/sample - loss: 0.0330 - accuracy: 0.9953
# Epoch 76/100
# 423/423 [==============================] - 0s 261us/sample - loss: 0.0329 - accuracy: 0.9905
# Epoch 77/100
# 423/423 [==============================] - 0s 359us/sample - loss: 0.0328 - accuracy: 0.9905
# Epoch 78/100
# 423/423 [==============================] - 0s 451us/sample - loss: 0.0327 - accuracy: 0.9905
# Epoch 79/100
# 423/423 [==============================] - 0s 416us/sample - loss: 0.0326 - accuracy: 0.9905
# Epoch 80/100
# 423/423 [==============================] - 0s 383us/sample - loss: 0.0323 - accuracy: 0.9929
# Epoch 81/100
# 423/423 [==============================] - 0s 333us/sample - loss: 0.0323 - accuracy: 0.9858
# Epoch 82/100
# 423/423 [==============================] - 0s 352us/sample - loss: 0.0322 - accuracy: 0.9953
# Epoch 83/100
# 423/423 [==============================] - 0s 249us/sample - loss: 0.0321 - accuracy: 0.9905
# Epoch 84/100
# 423/423 [==============================] - 0s 365us/sample - loss: 0.0320 - accuracy: 0.9905
# Epoch 85/100
# 423/423 [==============================] - 0s 333us/sample - loss: 0.0320 - accuracy: 0.9953
# Epoch 86/100
# 423/423 [==============================] - 0s 311us/sample - loss: 0.0318 - accuracy: 0.9953
# Epoch 87/100
# 423/423 [==============================] - 0s 437us/sample - loss: 0.0321 - accuracy: 0.9882
# Epoch 88/100
# 423/423 [==============================] - 0s 340us/sample - loss: 0.0317 - accuracy: 0.9976
# Epoch 89/100
# 423/423 [==============================] - 0s 375us/sample - loss: 0.0316 - accuracy: 0.9882
# Epoch 90/100
# 423/423 [==============================] - 0s 345us/sample - loss: 0.0315 - accuracy: 0.9953
# Epoch 91/100
# 423/423 [==============================] - 0s 381us/sample - loss: 0.0314 - accuracy: 0.9882
# Epoch 92/100
# 423/423 [==============================] - 0s 318us/sample - loss: 0.0314 - accuracy: 0.9953
# Epoch 93/100
# 423/423 [==============================] - 0s 313us/sample - loss: 0.0314 - accuracy: 0.9905
# Epoch 94/100
# 423/423 [==============================] - 0s 391us/sample - loss: 0.0315 - accuracy: 0.9953
# Epoch 95/100
# 423/423 [==============================] - 0s 274us/sample - loss: 0.0319 - accuracy: 0.9929
# Epoch 96/100
# 423/423 [==============================] - 0s 409us/sample - loss: 0.0325 - accuracy: 0.9976
# Epoch 97/100
# 423/423 [==============================] - 0s 264us/sample - loss: 0.0324 - accuracy: 0.9929
# Epoch 98/100
# 423/423 [==============================] - 0s 487us/sample - loss: 0.0321 - accuracy: 0.9929
# Epoch 99/100
# 423/423 [==============================] - 0s 430us/sample - loss: 0.0317 - accuracy: 0.9882
# Epoch 100/100
# 423/423 [==============================] - 0s 394us/sample - loss: 0.0324 - accuracy: 0.9953
# WARNING:tensorflow:From /Users/blakemyers/opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: texts/english_model/assets
# 423/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Accuracy: 98.82 , % Loss: 3.18 %
#
# FINAL DTATA SHAPES X (423, 415) y (423, 25)
#
#
#
#
# ALGORITHMICALLY DERIVED ANSWERS:
#
# Query: What do I fear above all things?
#
# HIT COUNTS: Counter({24: 4})
#
# 24 : I admit it: above all things, I fear absurdity.
#
# Query: What celebrated my arrival?
#
# HIT COUNTS: Counter({14: 2})
#
# 14 : Soothsayers had prophesied me, newspapers celebrated my arrival, politicos ratified my authenticity.
#
# Query: At what time of day was I born?
#
# HIT COUNTS: Counter({0: 2, 2: 2})
#
# 0 : I was born in the city of Bombay … once upon a time.
# 2 : I was born in Doctor Narlikar’s Nursing Home on August 15th, 1947.
#
# Query: What has no further use for me and is running out?
#
# HIT COUNTS: Counter({18: 7})
#
# 18 : Now, however, time (having no further use for me) is running out.
#
# Query: Which doctor had a nursing home I was born in?
#
# HIT COUNTS: Counter({0: 2, 2: 2})
#
# 0 : I was born in the city of Bombay … once upon a time.
# 2 : I was born in Doctor Narlikar’s Nursing Home on August 15th, 1947.
#
# Query: Who prophesied me?
#
# HIT COUNTS: Counter({14: 1})
#
# 14 : Soothsayers had prophesied me, newspapers celebrated my arrival, politicos ratified my authenticity.
#
# Query: What type of home was I born in?
#
# HIT COUNTS: Counter({0: 2, 2: 2})
#
# 0 : I was born in the city of Bombay … once upon a time.
# 2 : I was born in Doctor Narlikar’s Nursing Home on August 15th, 1947.
#
# Query: Who broke his toe?
#
# HIT COUNTS: Counter({12: 2})
#
# 12 : A few seconds later, my father broke his big toe; but his accident was a mere trifle when set beside what had befallen me in that benighted moment, because thanks to the occult tyrannies of those blandly saluting clocks I had been mysteriously handcuffed to history, my destinies indissolubly chained to those of my country.
#
# Query: What city was I born in?
#
# HIT COUNTS: Counter({0: 4, 2: 2})
#
# 0 : I was born in the city of Bombay … once upon a time.
# 2 : I was born in Doctor Narlikar’s Nursing Home on August 15th, 1947.
#
# Query: What is crumbling and overused?
#
# HIT COUNTS: Counter()
#
#
#
#
# NEURAL NET'S ANSWERS:
#
# Query: What do I fear above all things?
#
# HIT COUNTS: Counter({24: 7, 0: 2})
#
# 24 : I admit it: above all things, I fear absurdity.
# 0 : I was born in the city of Bombay … once upon a time.
#
# Query: What celebrated my arrival?
#
# HIT COUNTS: Counter({0: 2, 14: 2, 12: 1, 3: 1})
#
# 0 : I was born in the city of Bombay … once upon a time.
# 14 : Soothsayers had prophesied me, newspapers celebrated my arrival, politicos ratified my authenticity.
# 12 : A few seconds later, my father broke his big toe; but his accident was a mere trifle when set beside what had befallen me in that benighted moment, because thanks to the occult tyrannies of those blandly saluting clocks I had been mysteriously handcuffed to history, my destinies indissolubly chained to those of my country.
#
# Query: At what time of day was I born?
#
# HIT COUNTS: Counter({2: 4, 0: 3, 16: 2, 17: 1})
#
# 2 : I was born in Doctor Narlikar’s Nursing Home on August 15th, 1947.
# 0 : I was born in the city of Bombay … once upon a time.
# 16 : I, Saleem Sinai, later variously called Snotnose, Stainface, Baldy, Sniffer, Buddha and even Piece-of-the-Moon, had become heavily embroiled in Fate—at the best of times a dangerous sort of involvement.
#
# Query: What has no further use for me and is running out?
#
# HIT COUNTS: Counter({18: 10, 22: 2, 0: 1})
#
# 18 : Now, however, time (having no further use for me) is running out.
# 22 : But I have no hope of saving my life, nor can I count on having even a thousand nights and a night.
# 0 : I was born in the city of Bombay … once upon a time.
#
# Query: Which doctor had a nursing home I was born in?
#
# HIT COUNTS: Counter({0: 5, 2: 4, 8: 3, 22: 2, 12: 1, 18: 1})
#
# 0 : I was born in the city of Bombay … once upon a time.
# 2 : I was born in Doctor Narlikar’s Nursing Home on August 15th, 1947.
# 8 : Clock-hands joined palms in respectful greeting as I came.
#
# Query: Who prophesied me?
#
# HIT COUNTS: Counter({14: 4})
#
# 14 : Soothsayers had prophesied me, newspapers celebrated my arrival, politicos ratified my authenticity.
#
# Query: What type of home was I born in?
#
# HIT COUNTS: Counter({0: 3, 2: 3, 12: 2, 16: 1, 15: 1})
#
# 0 : I was born in the city of Bombay … once upon a time.
# 2 : I was born in Doctor Narlikar’s Nursing Home on August 15th, 1947.
# 12 : A few seconds later, my father broke his big toe; but his accident was a mere trifle when set beside what had befallen me in that benighted moment, because thanks to the occult tyrannies of those blandly saluting clocks I had been mysteriously handcuffed to history, my destinies indissolubly chained to those of my country.
#
# Query: Who broke his toe?
#
# HIT COUNTS: Counter({12: 5, 0: 1})
#
# 12 : A few seconds later, my father broke his big toe; but his accident was a mere trifle when set beside what had befallen me in that benighted moment, because thanks to the occult tyrannies of those blandly saluting clocks I had been mysteriously handcuffed to history, my destinies indissolubly chained to those of my country.
# 0 : I was born in the city of Bombay … once upon a time.
#
# Query: What city was I born in?
#
# HIT COUNTS: Counter({0: 5, 2: 3})
#
# 0 : I was born in the city of Bombay … once upon a time.
# 2 : I was born in Doctor Narlikar’s Nursing Home on August 15th, 1947.
#
# Query: What is crumbling and overused?
#
# HIT COUNTS: Counter({21: 4, 0: 1, 3: 1})
#
# 21 : If my crumbling, overused body permits.
# 0 : I was born in the city of Bombay … once upon a time.
# 3 : And the time?
